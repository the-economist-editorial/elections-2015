# %%
import pandas as pd
import numpy as np
import os

# %%
files = os.listdir('turkey_20151113')

# %%
files[:5]
# Out:
# ['ssps-13-11-2015-12-33.Normal.xls',
#  'ssps-13-11-2015-13-00.Normal (1).xls',
#  'ssps-13-11-2015-13-00.Normal.xls',
#  'ssps-13-11-2015-13-01.Normal (1).xls',
#  'ssps-13-11-2015-13-01.Normal.xls']

# %%
all = [pd.read_excel('turkey_20151113/'+file) for file in files]

# %%
all
# Out:
# [                          13/11/2015 12:33:39 Unnamed: 1 Unnamed: 2  \
#  İL ADI İLÇE ADI   MİLLET        VATAN PARTİSİ        CHP    HAK-PAR
#  ADANA  ALADAĞ     4                        18      1.302         33
#         CEYHAN     30                      236     25.540        193
#         ÇUKUROVA   116                     778     97.189        313
#         FEKE       3                        29      1.549         55
#         İMAMOĞLU   6                        14      3.092         54
#         KARAİSALI  5                        18      1.340         32
#         KARATAŞ    11                       17      5.342         30
#         KOZAN      42                      139     13.629        217
#         POZANTI    13                       24      2.554         46
#         SAİMBEYLİ  5                        29        979         32
#         SARIÇAM    36                       96     13.044        127
#         SEYHAN     136                   1.014    147.957        862
# ...

# %%
pd.concat(all)
# Out:
#                                              13/11/2015 12:33:39  \
# İL ADI         İLÇE ADI              MİLLET        VATAN PARTİSİ
# ADANA          ALADAĞ                4                        18
#                CEYHAN                30                      236
#                ÇUKUROVA              116                     778
#                FEKE                  3                        29
#                İMAMOĞLU              6                        14
#                KARAİSALI             5                        18
#                KARATAŞ               11                       17
#                KOZAN                 42                      139
#                POZANTI               13                       24
#                SAİMBEYLİ             5                        29
#                SARIÇAM               36                       96
#                SEYHAN                136                   1.014
# ...
